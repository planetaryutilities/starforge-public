# %%
import numpy as np

from secretaries.workspace import Workspace
from starkit_domain.starkit_classes import Nexus
from solari_registry import (
    ThermalUnit,
    FuelTankInside,
    FuelTankOutside,
    Compute,
    Transporter,
    PowerUnit,
    BHT40
) 
import geometry_api as ga
from solari_registry.thermal_solari import change_radiator_angle
from solari_registry.power_solari import add_solar_membrane
from starkit_domain.molecule_functions import add_solari, add_nexus, commit_sysml, retrieve_latest_commit_sysml, generate_omniverse
# Out:
# Retriever is loading...
# did = '5ec100e212a5fab5ff355415'
# wvm = 'w'
# wvmid = '8d575323d1374d8294794c4e'
# eid = 'c3f9ece31fa2da7e84db29b5'

# %%
workspace = Workspace.get_instance()
workspace.enable_sedaro = False
workspace.enable_flexo = True
workspace.is_jupyter = True

# %%
nx1 = Nexus('NX0001')

add_nexus(nx1, None)

add_solari(PowerUnit) 
add_solari(PowerUnit) 

add_solari(FuelTankInside)
add_solari(FuelTankOutside)

add_solari(Compute)
add_solari(Transporter)

add_solari(ThermalUnit)
add_solari(ThermalUnit)

# rendering is currently not support so you'll get and error
# Out:
# 2026-03-12 22:34:35.086 (   9.326s) [    73065B48FE00]vtkXOpenGLRenderWindow.:1458  WARN| bad X server connection. DISPLAY=:99
# 2026-03-12 22:34:35.086 (   9.327s) [    73065B48FE00]vtkOpenGLRenderWindow.c:649   WARN| Failed to load EGL! Please install the EGL library from your distribution's package manager.
# 2026-03-12 22:34:35.086 (   9.327s) [    73065B48FE00]vtkOSOpenGLRenderWindow:152   WARN| libOSMesa not found. It appears that OSMesa is not installed in your system. Please install the OSMesa library from your distribution's package manager.
# Connecting PowerUnit with ID PWR00001 to Nexus.
# Connecting PowerUnit with ID PWR00002 to Nexus.
# Connecting FuelTankInside with ID FTK00003 to Nexus.
# Connecting FuelTankOutside with ID FTK00004 to Nexus.
# Connecting Compute with ID CMP00005 to Nexus.
# Connecting Transporter with ID TRP00006 to Nexus.
# Connecting ThermalUnit with ID TCS00007 to Nexus.
# Connecting ThermalUnit with ID TCS00008 to Nexus.

# %%
bearer_token = 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhdWQiOiJmbGV4by1tbXMiLCJpc3MiOiJodHRwOi8vbG9jYWxob3N0OjgwODAvIiwidXNlcm5hbWUiOiJyb290IiwiZ3JvdXBzIjpbInN1cGVyX2FkbWlucyJdLCJleHAiOjE4MDI5Mzc2MDB9.ImUGueRS61iqdTYpndJGfZo44Y7hcWEiDzleOwbziRI'
flexo_url_dev = 'http://sysmlv2-service-svc.user-rkarban.svc.cluster.local:8080'
workspace.set_flexo_environment('rkatest100', project_id=None, api_key=bearer_token,
                                 flexo_url=flexo_url_dev, user_name='rkarban', ov_host=None)

# %%
commit_sysml()
# Out:
# Generating SYSML for Nexus NX0001...
# outside
# inside
# outside
# inside
# outside
# inside
# outside
# inside
# Creating sysml package:  MoleculeGeometryModel
# ____ SYSML TEXT ____
# package MoleculeGeometryModel {
#
#
#     part def Onshape_Component {
#         attribute onshape_url;
#     }
#     part def Omniverse_Component {
#         attribute ov_filepath;
#     }
#
#     part def Component{
#         attribute tx;
#         attribute ty;
#         attribute tz;
#
#         attribute rx;
#         attribute ry;
#         attribute rz;
#
#         attribute typeID;
#         part children: Component[0..*];
#     }
#
#
#      part def Context {
#         part geometryroot :Component {
#             part NX0001: Onshape_Component, Omniverse_Component subsets children {
#                 attribute :>> tx=0.0;
#                 attribute :>> ty=0.0;
#                 attribute :>> tz=0.0;
#                 attribute :>> rx=0.0;
#                 attribute :>> ry=0.0;
# ...
